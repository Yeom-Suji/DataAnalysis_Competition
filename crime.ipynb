# %% [markdown]
# # 내가 살 곳은 안전한가?

# %%
import numpy as np
import pandas as pd

# %%
crime_anal= pd.read_csv(r"C:\Users\LG\Desktop\공모전\data\5대+범죄+발생현황_20231030131017.csv", thousands=',', encoding='utf-8')
crime_anal
# Out:
#       구별  소계 발생  소계 검거  살인 발생  살인 검거  강도 발생  강도 검거  강간·강제추행 발생  강간·강제추행 검거  \
# 0     소계  90399  65097    104     98    117    112        5816        5344
# 1    종로구   3138   3284      2      3      8      8         228         988
# 2     중구   3071   2119      1      2      5      4         194         123
# 3    용산구   2967   2093      5      3      7      7         280         238
# 4    성동구   2194   1597      2      2      2      2         125          97
# 5    광진구   3619   2498      6      5      0      0         230         174
# 6   동대문구   3253   2231      4      4      2      2         125         106
# 7    중랑구   3599   2671      2      2      2      2         150         121
# 8    성북구   2749   2125      3      3      1      1         158         129
# 9    강북구   2832   2343      5      4      5      6         177         147
# 10   도봉구   2141   1569      3      3      0      0          70          54
# ...

# %%
crime_anal.drop(0, inplace=True) 
crime_anal
# Out:
#       구별  소계 발생  소계 검거  살인 발생  살인 검거  강도 발생  강도 검거  강간·강제추행 발생  강간·강제추행 검거  \
# 1    종로구   3138   3284      2      3      8      8         228         988
# 2     중구   3071   2119      1      2      5      4         194         123
# 3    용산구   2967   2093      5      3      7      7         280         238
# 4    성동구   2194   1597      2      2      2      2         125          97
# 5    광진구   3619   2498      6      5      0      0         230         174
# 6   동대문구   3253   2231      4      4      2      2         125         106
# 7    중랑구   3599   2671      2      2      2      2         150         121
# 8    성북구   2749   2125      3      3      1      1         158         129
# 9    강북구   2832   2343      5      4      5      6         177         147
# 10   도봉구   2141   1569      3      3      0      0          70          54
# 11   노원구   3896   2641      3      3      3      1         180         151
# ...

# %%
crime_anal.drop(columns=crime_anal.columns[1], inplace=True)
crime_anal
# Out:
#       구별  소계 검거  살인 발생  살인 검거  강도 발생  강도 검거  강간·강제추행 발생  강간·강제추행 검거  절도 발생  \
# 1    종로구   3284      2      3      8      8         228         988   1313
# 2     중구   2119      1      2      5      4         194         123   1365
# 3    용산구   2093      5      3      7      7         280         238    978
# 4    성동구   1597      2      2      2      2         125          97    979
# 5    광진구   2498      6      5      0      0         230         174   1670
# 6   동대문구   2231      4      4      2      2         125         106   1556
# 7    중랑구   2671      2      2      2      2         150         121   1508
# 8    성북구   2125      3      3      1      1         158         129   1143
# 9    강북구   2343      5      4      5      6         177         147    872
# 10   도봉구   1569      3      3      0      0          70          54    969
# 11   노원구   2641      3      3      3      1         180         151   1504
# ...

# %%
crime_anal.drop(columns=crime_anal.columns[1], inplace=True)
crime_anal
# Out:
#       구별  살인 발생  살인 검거  강도 발생  강도 검거  강간·강제추행 발생  강간·강제추행 검거  절도 발생  절도 검거  \
# 1    종로구      2      3      8      8         228         988   1313    932
# 2     중구      1      2      5      4         194         123   1365    724
# 3    용산구      5      3      7      7         280         238    978    508
# 4    성동구      2      2      2      2         125          97    979    538
# 5    광진구      6      5      0      0         230         174   1670    831
# 6   동대문구      4      4      2      2         125         106   1556    823
# 7    중랑구      2      2      2      2         150         121   1508    882
# 8    성북구      3      3      1      1         158         129   1143    715
# 9    강북구      5      4      5      6         177         147    872    589
# 10   도봉구      3      3      0      0          70          54    969    546
# 11   노원구      3      3      3      1         180         151   1504    729
# ...

# %%
crime_anal = crime_anal.set_index('구별', drop=True)
crime_anal
# Out:
#       살인 발생  살인 검거  강도 발생  강도 검거  강간·강제추행 발생  강간·강제추행 검거  절도 발생  절도 검거  폭력 발생  \
# 구별
# 종로구       2      3      8      8         228         988   1313    932   1587
# 중구        1      2      5      4         194         123   1365    724   1506
# 용산구       5      3      7      7         280         238    978    508   1697
# 성동구       2      2      2      2         125          97    979    538   1086
# 광진구       6      5      0      0         230         174   1670    831   1713
# 동대문구      4      4      2      2         125         106   1556    823   1566
# 중랑구       2      2      2      2         150         121   1508    882   1937
# 성북구       3      3      1      1         158         129   1143    715   1444
# 강북구       5      4      5      6         177         147    872    589   1773
# 도봉구       3      3      0      0          70          54    969    546   1099
# 노원구       3      3      3      1         180         151   1504    729   2206
# ...

# %%
crime_anal.describe()
# Out:
#            살인 발생      살인 검거      강도 발생      강도 검거  강간·강제추행 발생  강간·강제추행 검거  \
# count  25.000000  25.000000  25.000000  25.000000   25.000000   25.000000
# mean    4.160000   3.920000   4.680000   4.480000  232.640000  213.760000
# std     2.910899   2.531798   3.023795   3.015515  129.660737  192.811065
# min     1.000000   1.000000   0.000000   0.000000   70.000000   54.000000
# 25%     2.000000   2.000000   2.000000   2.000000  157.000000  121.000000
# 50%     3.000000   3.000000   5.000000   4.000000  194.000000  146.000000
# 75%     5.000000   4.000000   7.000000   7.000000  280.000000  237.000000
# max    12.000000  11.000000  11.000000  10.000000  667.000000  988.000000
#
#              절도 발생        절도 검거        폭력 발생        폭력 검거
# count    25.000000    25.000000    25.000000    25.000000
# mean   1503.160000   808.200000  1871.320000  1573.520000
# std     422.806465   202.419943   600.421499   511.940436
# min     872.000000   508.000000  1086.000000   886.000000
# ...

# %%
crime_anal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25 entries, 종로구 to 강동구
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   살인 발생       25 non-null     int64
#  1   살인 검거       25 non-null     int64
#  2   강도 발생       25 non-null     int64
#  3   강도 검거       25 non-null     int64
#  4   강간·강제추행 발생  25 non-null     int64
#  5   강간·강제추행 검거  25 non-null     int64
#  6   절도 발생       25 non-null     int64
#  7   절도 검거       25 non-null     int64
#  8   폭력 발생       25 non-null     int64
#  9   폭력 검거       25 non-null     int64
# dtypes: int64(10)
# memory usage: 2.1+ KB

# %% [markdown]
# # 범죄 데이터 구별로 정리하기

# %%
import pandas as pd

columns_to_convert = [
    '강간·강제추행 검거', '강간·강제추행 발생',
    '살인 검거', '살인 발생',
    '절도 검거', '절도 발생',
    '폭력 검거', '폭력 발생',
    '강도 검거', '강도 발생'
]

crime_anal[columns_to_convert] = crime_anal[columns_to_convert].apply(pd.to_numeric, errors='coerce')

crime_anal['강간·강제추행 검거율'] = crime_anal['강간·강제추행 검거'] / crime_anal['강간·강제추행 발생'] * 100
crime_anal['살인검거율'] = crime_anal['살인 검거'] / crime_anal['살인 발생'] * 100
crime_anal['절도검거율'] = crime_anal['절도 검거'] / crime_anal['절도 발생'] * 100
crime_anal['폭력검거율'] = crime_anal['폭력 검거'] / crime_anal['폭력 발생'] * 100
crime_anal['강도검거율'] = crime_anal['강도 검거'] / crime_anal['강도 발생'] * 100

columns_to_remove = [
    '강간·강제추행 검거', '살인 검거',
    '절도 검거', '폭력 검거',
    '강도 검거'
]
crime_anal.drop(columns=columns_to_remove, inplace=True)

crime_anal.head()
# Out:
#      살인 발생  강도 발생  강간·강제추행 발생  절도 발생  폭력 발생  강간·강제추행 검거율       살인검거율  \
# 구별
# 종로구      2      8         228   1313   1587   433.333333  150.000000
# 중구       1      5         194   1365   1506    63.402062  200.000000
# 용산구      5      7         280    978   1697    85.000000   60.000000
# 성동구      2      2         125    979   1086    77.600000  100.000000
# 광진구      6      0         230   1670   1713    75.652174   83.333333
#
#          절도검거율      폭력검거율  강도검거율
# 구별
# 종로구  70.982483  85.255198  100.0
# 중구   53.040293  84.063745   80.0
# 용산구  51.942740  78.786093  100.0
# 성동구  54.954035  88.213628  100.0
# 광진구  49.760479  86.865149    NaN

# %%
con_list = ['강간·강제추행 검거율', '살인검거율', '절도검거율', '폭력검거율']

for column in con_list:
    crime_anal.loc[crime_anal[column] > 100, column] = 100
    
crime_anal.head()
# Out:
#      살인 발생  강도 발생  강간·강제추행 발생  절도 발생  폭력 발생  강간·강제추행 검거율       살인검거율  \
# 구별
# 종로구      2      8         228   1313   1587   100.000000  100.000000
# 중구       1      5         194   1365   1506    63.402062  100.000000
# 용산구      5      7         280    978   1697    85.000000   60.000000
# 성동구      2      2         125    979   1086    77.600000  100.000000
# 광진구      6      0         230   1670   1713    75.652174   83.333333
#
#          절도검거율      폭력검거율  강도검거율
# 구별
# 종로구  70.982483  85.255198  100.0
# 중구   53.040293  84.063745   80.0
# 용산구  51.942740  78.786093  100.0
# 성동구  54.954035  88.213628  100.0
# 광진구  49.760479  86.865149    NaN

# %%
crime_anal.rename(columns = {'강간·강제추행 발생':'강간·강제추행', 
                             '강도 발생':'강도', 
                             '살인 발생':'살인', 
                             '절도 발생':'절도', 
                             '폭력 발생':'폭력'}, inplace=True)
crime_anal.head()
# Out:
#      살인  강도  강간·강제추행    절도    폭력  강간·강제추행 검거율       살인검거율      절도검거율  \
# 구별
# 종로구   2   8      228  1313  1587   100.000000  100.000000  70.982483
# 중구    1   5      194  1365  1506    63.402062  100.000000  53.040293
# 용산구   5   7      280   978  1697    85.000000   60.000000  51.942740
# 성동구   2   2      125   979  1086    77.600000  100.000000  54.954035
# 광진구   6   0      230  1670  1713    75.652174   83.333333  49.760479
#
#          폭력검거율  강도검거율
# 구별
# 종로구  85.255198  100.0
# 중구   84.063745   80.0
# 용산구  78.786093  100.0
# 성동구  88.213628  100.0
# 광진구  86.865149    NaN

# %%
from sklearn import preprocessing
import pandas as pd


col_crime = ['강간·강제추행', '강도', '살인', '절도', '폭력']

col_detection = ['강간·강제추행 검거율', '강도검거율', '살인검거율', '절도검거율', '폭력검거율']

x_crime = crime_anal[col_crime].values
min_max_scaler_crime = preprocessing.MinMaxScaler()
x_scaled_crime = min_max_scaler_crime.fit_transform(x_crime)
crime_anal_norm_crime = pd.DataFrame(x_scaled_crime, columns=col_crime, index=crime_anal.index)


crime_anal_norm = crime_anal_norm_crime

crime_anal_norm[col_detection] = crime_anal[col_detection]
crime_anal_norm
# Out:
#        강간·강제추행        강도        살인        절도        폭력  강간·강제추행 검거율  \
# 구별
# 종로구   0.264657  0.727273  0.090909  0.271719  0.187220   100.000000
# 중구    0.207705  0.454545  0.000000  0.303758  0.156951    63.402062
# 용산구   0.351759  0.636364  0.363636  0.065311  0.228326    85.000000
# 성동구   0.092127  0.181818  0.090909  0.065927  0.000000    77.600000
# 광진구   0.268007  0.000000  0.454545  0.491682  0.234305    75.652174
# 동대문구  0.092127  0.181818  0.272727  0.421442  0.179372    84.800000
# 중랑구   0.134003  0.181818  0.090909  0.391867  0.318012    80.666667
# 성북구   0.147404  0.090909  0.181818  0.166975  0.133782    81.645570
# 강북구   0.179229  0.454545  0.363636  0.000000  0.256726    83.050847
# 도봉구   0.000000  0.000000  0.181818  0.059766  0.004858    77.142857
# 노원구   0.184255  0.272727  0.181818  0.389402  0.418535    83.888889
# 은평구   0.177554  0.454545  0.272727  0.385089  0.268685    82.954545
# 서대문구  0.145729  0.545455  0.363636  0.149107  0.002242    91.719745
# ...

# %%
result_CCTV = pd.read_csv(r"C:\Users\LG\Desktop\공모전\data\pop_cctv.csv", encoding='UTF-8', index_col='구별')
result_CCTV
# Out:
#       2023년     총계       최근증가율     인구수      합계     한국인    외국인      외국인비율
# 구별
# 종로구    1808  12578   70.318213   72304  151127  139945  11182  15.465258
# 중구     2026  11627  105.278955   64609  131825  121405  10420  16.127784
# 용산구    2647  18278   69.570461  109360  230692  216152  14540  13.295538
# 성동구    3643  23694   83.603255  133366  285543  278366   7177   5.381432
# 광진구    3359  18622  112.047370  170388  351959  336604  15355   9.011785
# 동대문구   2592  17819   75.314837  173091  359113  341238  17875  10.326938
# 중랑구    3856  20618  121.365686  187900  387940  382797   5143   2.737094
# 성북구    4129  25687   87.100299  197607  440089  427671  12418   6.284190
# 강북구    3184  16769  125.359495  144269  294804  290155   4649   3.222453
# 도봉구    2120   9831  143.763947  138210  310133  307740   2393   1.731423
# 노원구    2281  15767   74.587532  218367  504423  499989   4434   2.030527
# 은평구    4103  27373   78.383838  215776  471155  467098   4057   1.880191
# ...

# %%
crime_anal_norm[['인구수', '2023']] = result_CCTV[['인구수', '총계']]
crime_anal_norm.head()
# Out:
#       강간·강제추행        강도        살인        절도        폭력  강간·강제추행 검거율  강도검거율  \
# 구별
# 종로구  0.264657  0.727273  0.090909  0.271719  0.187220   100.000000  100.0
# 중구   0.207705  0.454545  0.000000  0.303758  0.156951    63.402062   80.0
# 용산구  0.351759  0.636364  0.363636  0.065311  0.228326    85.000000  100.0
# 성동구  0.092127  0.181818  0.090909  0.065927  0.000000    77.600000  100.0
# 광진구  0.268007  0.000000  0.454545  0.491682  0.234305    75.652174    NaN
#
#           살인검거율      절도검거율      폭력검거율     인구수   2023
# 구별
# 종로구  100.000000  70.982483  85.255198   72304  12578
# 중구   100.000000  53.040293  84.063745   64609  11627
# 용산구   60.000000  51.942740  78.786093  109360  18278
# 성동구  100.000000  54.954035  88.213628  133366  23694
# 광진구   83.333333  49.760479  86.865149  170388  18622

# %%
col = ['강간·강제추행','강도','살인','절도','폭력']
crime_anal_norm['범죄'] = np.sum(crime_anal_norm[col], axis=1)
crime_anal_norm.head()
# Out:
#       강간·강제추행        강도        살인        절도        폭력  강간·강제추행 검거율  강도검거율  \
# 구별
# 종로구  0.264657  0.727273  0.090909  0.271719  0.187220   100.000000  100.0
# 중구   0.207705  0.454545  0.000000  0.303758  0.156951    63.402062   80.0
# 용산구  0.351759  0.636364  0.363636  0.065311  0.228326    85.000000  100.0
# 성동구  0.092127  0.181818  0.090909  0.065927  0.000000    77.600000  100.0
# 광진구  0.268007  0.000000  0.454545  0.491682  0.234305    75.652174    NaN
#
#           살인검거율      절도검거율      폭력검거율     인구수   2023        범죄
# 구별
# 종로구  100.000000  70.982483  85.255198   72304  12578  1.541777
# 중구   100.000000  53.040293  84.063745   64609  11627  1.122960
# 용산구   60.000000  51.942740  78.786093  109360  18278  1.645396
# 성동구  100.000000  54.954035  88.213628  133366  23694  0.430782
# 광진구   83.333333  49.760479  86.865149  170388  18622  1.448539

# %%
col = ['강간·강제추행 검거율','강도검거율','살인검거율','절도검거율','폭력검거율']
crime_anal_norm['검거'] = np.sum(crime_anal_norm[col], axis=1)
crime_anal_norm.head()
# Out:
#       강간·강제추행        강도        살인        절도        폭력  강간·강제추행 검거율  강도검거율  \
# 구별
# 종로구  0.264657  0.727273  0.090909  0.271719  0.187220   100.000000  100.0
# 중구   0.207705  0.454545  0.000000  0.303758  0.156951    63.402062   80.0
# 용산구  0.351759  0.636364  0.363636  0.065311  0.228326    85.000000  100.0
# 성동구  0.092127  0.181818  0.090909  0.065927  0.000000    77.600000  100.0
# 광진구  0.268007  0.000000  0.454545  0.491682  0.234305    75.652174    NaN
#
#           살인검거율      절도검거율      폭력검거율     인구수   2023        범죄          검거
# 구별
# 종로구  100.000000  70.982483  85.255198   72304  12578  1.541777  456.237681
# 중구   100.000000  53.040293  84.063745   64609  11627  1.122960  380.506100
# 용산구   60.000000  51.942740  78.786093  109360  18278  1.645396  375.728833
# 성동구  100.000000  54.954035  88.213628  133366  23694  0.430782  420.767663
# 광진구   83.333333  49.760479  86.865149  170388  18622  1.448539  295.611135

# %%
crime_anal_norm
# Out:
#        강간·강제추행        강도        살인        절도        폭력  강간·강제추행 검거율  \
# 구별
# 종로구   0.264657  0.727273  0.090909  0.271719  0.187220   100.000000
# 중구    0.207705  0.454545  0.000000  0.303758  0.156951    63.402062
# 용산구   0.351759  0.636364  0.363636  0.065311  0.228326    85.000000
# 성동구   0.092127  0.181818  0.090909  0.065927  0.000000    77.600000
# 광진구   0.268007  0.000000  0.454545  0.491682  0.234305    75.652174
# 동대문구  0.092127  0.181818  0.272727  0.421442  0.179372    84.800000
# 중랑구   0.134003  0.181818  0.090909  0.391867  0.318012    80.666667
# 성북구   0.147404  0.090909  0.181818  0.166975  0.133782    81.645570
# 강북구   0.179229  0.454545  0.363636  0.000000  0.256726    83.050847
# 도봉구   0.000000  0.000000  0.181818  0.059766  0.004858    77.142857
# 노원구   0.184255  0.272727  0.181818  0.389402  0.418535    83.888889
# 은평구   0.177554  0.454545  0.272727  0.385089  0.268685    82.954545
# 서대문구  0.145729  0.545455  0.363636  0.149107  0.002242    91.719745
# ...

# %% [markdown]
# # Seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

import platform

path = "c:/Windows/Fonts/malgun.ttf"
from matplotlib import font_manager, rc
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# %%
crime_anal_norm.head()
# Out:
#       강간·강제추행        강도        살인        절도        폭력  강간·강제추행 검거율  강도검거율  \
# 구별
# 종로구  0.264657  0.727273  0.090909  0.271719  0.187220   100.000000  100.0
# 중구   0.207705  0.454545  0.000000  0.303758  0.156951    63.402062   80.0
# 용산구  0.351759  0.636364  0.363636  0.065311  0.228326    85.000000  100.0
# 성동구  0.092127  0.181818  0.090909  0.065927  0.000000    77.600000  100.0
# 광진구  0.268007  0.000000  0.454545  0.491682  0.234305    75.652174    NaN
#
#           살인검거율      절도검거율      폭력검거율     인구수   2023        범죄          검거
# 구별
# 종로구  100.000000  70.982483  85.255198   72304  12578  1.541777  456.237681
# 중구   100.000000  53.040293  84.063745   64609  11627  1.122960  380.506100
# 용산구   60.000000  51.942740  78.786093  109360  18278  1.645396  375.728833
# 성동구  100.000000  54.954035  88.213628  133366  23694  0.430782  420.767663
# 광진구   83.333333  49.760479  86.865149  170388  18622  1.448539  295.611135

# %%
sns.pairplot(crime_anal_norm, vars=["강도", "살인", "폭력"], kind='reg', size=3)
plt.show()
# Out:
# C:\Users\LG\anaconda3\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(crime_anal_norm, x_vars=["인구수", "2023"], 
             y_vars=["살인", "강도"], kind='reg', size=3)
plt.show()
# Out:
# C:\Users\LG\anaconda3\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(crime_anal_norm, x_vars=["인구수", "2023"], 
             y_vars=["살인검거율", "폭력검거율"], kind='reg', size=3)
plt.show()
# Out:
# C:\Users\LG\anaconda3\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(crime_anal_norm, x_vars=["인구수", "2023"], 
             y_vars=["절도검거율", "강도검거율"], kind='reg', size=3)
plt.show()
# Out:
# C:\Users\LG\anaconda3\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
tmp_max = crime_anal_norm['검거'].max()
crime_anal_norm['검거'] = crime_anal_norm['검거'] / tmp_max * 100
crime_anal_norm_sort = crime_anal_norm.sort_values(by='검거', ascending=False)
crime_anal_norm_sort.head()
# Out:
#       강간·강제추행        강도        살인        절도        폭력  강간·강제추행 검거율  강도검거율  \
# 구별
# 종로구  0.264657  0.727273  0.090909  0.271719  0.187220   100.000000  100.0
# 강북구  0.179229  0.454545  0.363636  0.000000  0.256726    83.050847  120.0
# 성북구  0.147404  0.090909  0.181818  0.166975  0.133782    81.645570  100.0
# 강서구  0.319933  0.636364  0.181818  0.689464  0.491405    74.712644  100.0
# 중랑구  0.134003  0.181818  0.090909  0.391867  0.318012    80.666667  100.0
#
#      살인검거율      절도검거율      폭력검거율     인구수   2023        범죄          검거
# 구별
# 종로구  100.0  70.982483  85.255198   72304  12578  1.541777  100.000000
# 강북구   80.0  67.545872  90.073322  144269  16769  1.254138   96.587822
# 성북구  100.0  62.554681  88.434903  197607  25687  0.720887   94.826703
# 강서구  100.0  59.517830  91.670137  274249  17512  2.318984   93.350600
# 중랑구  100.0  58.488064  85.906040  187900  20618  1.116609   93.166520

# %%
target_col = ['강간·강제추행 검거율', '강도검거율', '살인검거율', '절도검거율', '폭력검거율']

crime_anal_norm_sort = crime_anal_norm.sort_values(by='검거', ascending=False)

plt.figure(figsize = (9,7))
sns.heatmap(crime_anal_norm_sort[target_col], annot=True, fmt='f', 
                    linewidths=.5, cmap='RdPu')
plt.title('범죄 검거 비율')
plt.show()

# %%
target_col = ['강간·강제추행', '강도', '살인', '절도', '폭력', '범죄']

crime_anal_norm['범죄'] = crime_anal_norm['범죄'] / 5
crime_anal_norm_sort = crime_anal_norm.sort_values(by='범죄', ascending=False)

plt.figure(figsize = (9,7))
sns.heatmap(crime_anal_norm_sort[target_col], annot=True, fmt='f', linewidths=.5,
                       cmap='RdPu')
plt.title('범죄비율')
plt.show()

# %%
crime_anal_norm.to_csv(r"C:\Users\LG\Desktop\공모전\data\crime_result.csv", sep=',', 
                       encoding='utf-8')
